# %% [markdown]
# #將VGG16進行FineTune

# %% [markdown]
# ##載入VGG16模型

# %%
#VGG16
import tensorflow.keras
base_model = tensorflow.keras.applications.VGG16(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

base_model.summary()
# Out:
# ...
# 58892288/58889256 [==============================] - 0s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# ...

# %% [markdown]
# ##開始Fine-Tune VGG16

# %%
#VGG16
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.VGG16(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['block3_pool'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 2s 4ms/step - loss: 4.4416 - accuracy: 0.6389
# test_loss=4.441593170166016
# test_accuracy=0.6388999819755554

# %% [markdown]
# ##將VGG19進行FineTune

# %%
#VGG19
import tensorflow.keras
base_model = tensorflow.keras.applications.VGG19(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

base_model.summary()
# Out:
# ...
# 80142336/80134624 [==============================] - 1s 0us/step
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# ...

# %%
#VGG19
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.VGG19(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['block3_pool'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 1s 4ms/step - loss: 7.7273 - accuracy: 0.5455
# test_loss=7.727317810058594
# test_accuracy=0.5454999804496765

# %% [markdown]
# ##將ResNet50進行FineTune

# %%
#ResNet50
import tensorflow.keras
base_model = tensorflow.keras.applications.ResNet50(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

base_model.summary()
# Out:
# ...
# 94773248/94765736 [==============================] - 1s 0us/step
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_5 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 38, 38, 3)    0           input_5[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 16, 16, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#ResNet50
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D


# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.ResNet50(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['conv3_block4_out'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 2s 5ms/step - loss: 2.1214 - accuracy: 0.2581
# test_loss=2.121373414993286
# test_accuracy=0.2581000030040741

# %% [markdown]
# ##將ResNet101進行FineTune

# %%
#ResNet101
import tensorflow.keras
base_model = tensorflow.keras.applications.ResNet101(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

base_model.summary()
# Out:
# ...
# 171450368/171446536 [==============================] - 2s 0us/step
# Model: "resnet101"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_7 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 38, 38, 3)    0           input_7[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 16, 16, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#ResNet101
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D


# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.ResNet101(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['conv3_block4_out'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 2s 5ms/step - loss: 1.8544 - accuracy: 0.3983
# test_loss=1.8543673753738403
# test_accuracy=0.3982999920845032

# %% [markdown]
# ##將ResNet152進行FineTune

# %%
#ResNet152
import tensorflow.keras
base_model = tensorflow.keras.applications.ResNet152(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

base_model.summary()
# Out:
# ...
# 234700800/234698864 [==============================] - 3s 0us/step
# Model: "resnet152"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_9 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 38, 38, 3)    0           input_9[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 16, 16, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#ResNet152
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D


# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.ResNet152(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['conv3_block4_out'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 2s 5ms/step - loss: 2.2642 - accuracy: 0.3426
# test_loss=2.2642147541046143
# test_accuracy=0.3425999879837036

# %% [markdown]
# ##將ResNet50V2進行FineTune

# %%
#ResNet50
import tensorflow.keras
base_model = tensorflow.keras.applications.ResNet50V2(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

base_model.summary()
# Out:
# ...
# 94674944/94668760 [==============================] - 1s 0us/step
# Model: "resnet50v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_11 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 38, 38, 3)    0           input_11[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 16, 16, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 18, 18, 64)   0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#ResNet50V2
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D


# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.ResNet50V2(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['conv3_block4_out'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 2s 5ms/step - loss: 1.0102 - accuracy: 0.6493
# test_loss=1.010227084159851
# test_accuracy=0.6492999792098999

# %% [markdown]
# ##將ResNet101V2進行FineTune

# %%
#ResNet101V2
import tensorflow.keras
base_model = tensorflow.keras.applications.ResNet101V2(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

base_model.summary()
# Out:
# ...
# 171319296/171317808 [==============================] - 1s 0us/step
# Model: "resnet101v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_13 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 38, 38, 3)    0           input_13[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 16, 16, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 18, 18, 64)   0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#ResNet101V2
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D


# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.ResNet101V2(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['conv3_block4_out'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 2s 5ms/step - loss: 0.9962 - accuracy: 0.6567
# test_loss=0.996165931224823
# test_accuracy=0.6567000150680542

# %% [markdown]
# ##將ResNet152V2進行FineTune

# %%
#ResNet152V2
import tensorflow.keras
base_model = tensorflow.keras.applications.ResNet152V2(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

base_model.summary()
# Out:
# ...
# 234553344/234545216 [==============================] - 2s 0us/step
# Model: "resnet152v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_15 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 38, 38, 3)    0           input_15[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 16, 16, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 18, 18, 64)   0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#ResNet152V2
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D


# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.ResNet152V2(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['conv3_block4_out'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 2s 5ms/step - loss: 1.2207 - accuracy: 0.6132
# test_loss=1.220700740814209
# test_accuracy=0.6132000088691711

# %% [markdown]
# ##（需放大圖）將InceptionV3進行FineTune

# %%
#InceptionV3
import tensorflow.keras
#此處不能直接像之前模型一樣，因為InceptionV3所需圖檔大小至少要有75x75
#而Cifar10只有32x32
#若不修正則會出錯：ValueError: Input size must be at least 75x75; got `input_shape=(32, 32, 3)`
#base_model = tensorflow.keras.applications.InceptionV3(weights='imagenet',
#                               include_top=False,
#                               input_shape=(32, 32, 3))
base_model = tensorflow.keras.applications.InceptionV3(weights='imagenet',
                               include_top=False,
                               input_shape=(75, 75, 3))

base_model.summary()
# Out:
# ...
# 87916544/87910968 [==============================] - 1s 0us/step
# Model: "inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_17 (InputLayer)           [(None, 75, 75, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 37, 37, 32)   864         input_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 37, 37, 32)   96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 37, 37, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#InceptionV3
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D
from tensorflow.keras.models import Model

# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）

#重點是這裡要改
#此處不能直接像之前模型一樣，因為InceptionV3所需圖檔大小至少要有75x75
#而Cifar10只有32x32
#若不修正則會出錯：ValueError: Input size must be at least 75x75; got `input_shape=(32, 32, 3)`
#base_model = tensorflow.keras.applications.InceptionV3(weights='imagenet',
#                               include_top=False,
#                               input_shape=(32, 32, 3))
#此例特別將32x32的圖檔利用Keras的Lambda層長寬都擴增7倍=(224,224,3)
base_model = tensorflow.keras.applications.InceptionV3(weights='imagenet',
                               include_top=False,
                               input_shape=(224, 224, 3))

from tensorflow.keras import backend as K
from tensorflow.keras.layers import Lambda
#此例特別將32x32的圖檔利用Keras的Lambda層長寬都擴增7倍=(224,224,3)

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['mixed8'].output
base_model = Model(inputs=base_model.input, outputs=x)


#在這裡需使用正規的Functional Model定義方式
from tensorflow.keras.layers import Input
input_layer = Input(shape=(32,32,3))
x = Lambda(lambda img: K.resize_images(img, 7, 7, data_format='channels_last'), input_shape=(32, 32, 3))(input_layer)
x = base_model(x)
x = Flatten()(x)
x = Dense(10, activation='softmax')(x)


model = Model(inputs=input_layer, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 22s 63ms/step - loss: 0.3866 - accuracy: 0.8806
# test_loss=0.3866477906703949
# test_accuracy=0.8805999755859375

# %% [markdown]
# ##（需放大圖）將InceptionResNetV2進行FineTune

# %%
#InceptionResNetV2
import tensorflow.keras
#此處不能直接像之前模型一樣，因為InceptionV3所需圖檔大小至少要有75x75
#而Cifar10只有32x32
#若不修正則會出錯：ValueError: Input size must be at least 75x75; got `input_shape=(32, 32, 3)`
#base_model = tensorflow.keras.applications.InceptionV3(weights='imagenet',
#                               include_top=False,
#                               input_shape=(32, 32, 3))
base_model = tensorflow.keras.applications.InceptionResNetV2(weights='imagenet',
                               include_top=False,
                               input_shape=(75, 75, 3))

base_model.summary()
# Out:
# ...
# 219062272/219055592 [==============================] - 2s 0us/step
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_20 (InputLayer)           [(None, 75, 75, 3)]  0
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 37, 37, 32)   864         input_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 37, 37, 32)   96          conv2d_188[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 37, 37, 32)   0           batch_normalization_188[0][0]
# ...

# %%
#InceptionResNetV2
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D
from tensorflow.keras.models import Model

# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）

#重點是這裡要改
#此處不能直接像之前模型一樣，因為InceptionV3所需圖檔大小至少要有75x75
#而Cifar10只有32x32
#若不修正則會出錯：ValueError: Input size must be at least 75x75; got `input_shape=(32, 32, 3)`
#base_model = tensorflow.keras.applications.InceptionV3(weights='imagenet',
#                               include_top=False,
#                               input_shape=(32, 32, 3))
#此例特別將32x32的圖檔利用Keras的Lambda層長寬都擴增7倍=(224,224,3)
base_model = tensorflow.keras.applications.InceptionResNetV2(weights='imagenet',
                               include_top=False,
                               input_shape=(224, 224, 3))

from tensorflow.keras import backend as K
from tensorflow.keras.layers import Lambda
#此例特別將32x32的圖檔利用Keras的Lambda層長寬都擴增7倍=(224,224,3)

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['block8_8_mixed'].output
base_model = Model(inputs=base_model.input, outputs=x)


#在這裡需使用正規的Functional Model定義方式
from tensorflow.keras.layers import Input
input_layer = Input(shape=(32,32,3))
x = Lambda(lambda img: K.resize_images(img, 7, 7, data_format='channels_last'), input_shape=(32, 32, 3))(input_layer)
x = base_model(x)
x = Flatten()(x)
x = Dense(10, activation='softmax')(x)


model = Model(inputs=input_layer, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 57s 172ms/step - loss: 0.3830 - accuracy: 0.8690
# test_loss=0.3830282688140869
# test_accuracy=0.8690000176429749

# %% [markdown]
# ##（需放大圖）將Xception進行FineTune

# %%
#Xception
import tensorflow.keras
#此處不能直接像之前模型一樣，因為InceptionV3所需圖檔大小至少要有75x75
#而Cifar10只有32x32
#若不修正則會出錯：ValueError: Input size must be at least 75x75; got `input_shape=(32, 32, 3)`
#base_model = tensorflow.keras.applications.InceptionV3(weights='imagenet',
#                               include_top=False,
#                               input_shape=(32, 32, 3))
base_model = tensorflow.keras.applications.Xception(weights='imagenet',
                               include_top=False,
                               input_shape=(71, 71, 3))

base_model.summary()
# Out:
# ...
# 83689472/83683744 [==============================] - 1s 0us/step
# Model: "xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_23 (InputLayer)           [(None, 71, 71, 3)]  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 35, 35, 32)   864         input_23[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 35, 35, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 35, 35, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#Xception
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D
from tensorflow.keras.models import Model

# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）

#重點是這裡要改
#此處不能直接像之前模型一樣，因為Xception所需圖檔大小至少要有75x75
#而Cifar10只有32x32
#若不修正則會出錯：ValueError: Input size must be at least 75x75; got `input_shape=(32, 32, 3)`
#base_model = tensorflow.keras.applications.InceptionV3(weights='imagenet',
#                               include_top=False,
#                               input_shape=(32, 32, 3))
#此例特別將32x32的圖檔利用Keras的Lambda層長寬都擴增7倍=(224,224,3)
base_model = tensorflow.keras.applications.Xception(weights='imagenet',
                               include_top=False,
                               input_shape=(224, 224, 3))

from tensorflow.keras import backend as K
from tensorflow.keras.layers import Lambda
#此例特別將32x32的圖檔利用Keras的Lambda層長寬都擴增7倍=(224,224,3)

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['block11_sepconv3_bn'].output
base_model = Model(inputs=base_model.input, outputs=x)


#在這裡需使用正規的Functional Model定義方式
from tensorflow.keras.layers import Input
input_layer = Input(shape=(32,32,3))
x = Lambda(lambda img: K.resize_images(img, 7, 7, data_format='channels_last'), input_shape=(32, 32, 3))(input_layer)
x = base_model(x)
x = Flatten()(x)
x = Dense(10, activation='softmax')(x)


model = Model(inputs=input_layer, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 35s 108ms/step - loss: 4.8661 - accuracy: 0.7811
# test_loss=4.866142272949219
# test_accuracy=0.7810999751091003

# %% [markdown]
# ##將MobileNet進行FineTune

# %%
#MobileNet
import tensorflow.keras
base_model = tensorflow.keras.applications.MobileNet(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

base_model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# ...
# 17227776/17225924 [==============================] - 0s 0us/step
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_26 (InputLayer)        [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 16, 16, 32)        864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 16, 16, 32)        128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 16, 16, 32)        288
# ...

# %%
#MobileNet
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.MobileNet(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['conv_pw_11_relu'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# ...
# 313/313 [==============================] - 2s 5ms/step - loss: 1.1122 - accuracy: 0.6175
# test_loss=1.1121537685394287
# test_accuracy=0.6175000071525574

# %% [markdown]
# ##將MobileNetV2進行FineTune

# %%
#MobileNetV2
import tensorflow.keras
base_model = tensorflow.keras.applications.MobileNetV2(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

base_model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# ...
# 9412608/9406464 [==============================] - 0s 0us/step
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_28 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 16, 16, 32)   864         input_28[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 16, 16, 32)   128         Conv1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#MobileNetV2
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.MobileNetV2(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['block_14_add'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# ...
# 313/313 [==============================] - 3s 6ms/step - loss: 1.8101 - accuracy: 0.4495
# test_loss=1.8101423978805542
# test_accuracy=0.4494999945163727

# %% [markdown]
# ##將DenseNet121進行FineTune

# %%
#DenseNet121
import tensorflow.keras
base_model = tensorflow.keras.applications.DenseNet121(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

base_model.summary()
# Out:
# ...
# 29089792/29084464 [==============================] - 0s 0us/step
# Model: "densenet121"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_30 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 38, 38, 3)    0           input_30[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 16, 16, 64)   9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#DenseNet121
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.DenseNet121(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['conv5_block14_concat'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 8s 18ms/step - loss: 1.2835 - accuracy: 0.5768
# test_loss=1.2834737300872803
# test_accuracy=0.5767999887466431

# %% [markdown]
# ##將DenseNet169進行FineTune

# %%
#DenseNet169
import tensorflow.keras
base_model = tensorflow.keras.applications.DenseNet169(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

base_model.summary()
# Out:
# ...
# 51879936/51877672 [==============================] - 1s 0us/step
# Model: "densenet169"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_32 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 38, 38, 3)    0           input_32[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 16, 16, 64)   9408        zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#DenseNet169
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.DenseNet169(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['conv5_block14_concat'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 8s 20ms/step - loss: 1.2924 - accuracy: 0.5863
# test_loss=1.2924067974090576
# test_accuracy=0.5863000154495239

# %% [markdown]
# ##將DenseNet201進行FineTune

# %%
#DenseNet201
import tensorflow.keras
base_model = tensorflow.keras.applications.DenseNet201(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

base_model.summary()
# Out:
# ...
# 74842112/74836368 [==============================] - 1s 0us/step
# Model: "densenet201"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_34 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 38, 38, 3)    0           input_34[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 16, 16, 64)   9408        zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#DenseNet201
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.DenseNet201(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['conv5_block14_concat'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 11s 26ms/step - loss: 1.2762 - accuracy: 0.5826
# test_loss=1.2762013673782349
# test_accuracy=0.5825999975204468

# %% [markdown]
# ##（需放大圖）將NASNetMobile進行FineTune

# %%
#NASNetMobile
import tensorflow.keras
#此處不能直接像之前模型一樣，因為InceptionV3所需圖檔大小至少要有75x75
#而Cifar10只有32x32
#若不修正則會出錯：ValueError: Input size must be at least 75x75; got `input_shape=(32, 32, 3)`
#base_model = tensorflow.keras.applications.InceptionV3(weights='imagenet',
#                               include_top=False,
#                               input_shape=(32, 32, 3))
base_model = tensorflow.keras.applications.NASNetMobile(weights='imagenet',
                               include_top=False,
                               input_shape=(224, 224, 3))

base_model.summary()
# Out:
# ...
# 19996672/19993432 [==============================] - 0s 0us/step
# Model: "NASNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_36 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# stem_conv1 (Conv2D)             (None, 111, 111, 32) 864         input_36[0][0]
# __________________________________________________________________________________________________
# stem_bn1 (BatchNormalization)   (None, 111, 111, 32) 128         stem_conv1[0][0]
# __________________________________________________________________________________________________
# activation_594 (Activation)     (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#NASNetMobile
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D
from tensorflow.keras.models import Model

# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）

#重點是這裡要改
#此處不能直接像之前模型一樣，因為NASNetMobile所需圖檔大小至少要有224x224
#而Cifar10只有32x32
#若不修正則會出錯：ValueError: Input size must be at least 224x224; got `input_shape=(32, 32, 3)`
#base_model = tensorflow.keras.applications.InceptionV3(weights='imagenet',
#                               include_top=False,
#                               input_shape=(32, 32, 3))
#此例特別將32x32的圖檔利用Keras的Lambda層長寬都擴增7倍=(224,224,3)
base_model = tensorflow.keras.applications.NASNetMobile(weights='imagenet',
                               include_top=False,
                               input_shape=(224, 224, 3))

from tensorflow.keras import backend as K
from tensorflow.keras.layers import Lambda
#此例特別將32x32的圖檔利用Keras的Lambda層長寬都擴增7倍=(224,224,3)

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['normal_concat_11'].output
base_model = Model(inputs=base_model.input, outputs=x)


#在這裡需使用正規的Functional Model定義方式
from tensorflow.keras.layers import Input
input_layer = Input(shape=(32,32,3))
x = Lambda(lambda img: K.resize_images(img, 7, 7, data_format='channels_last'), input_shape=(32, 32, 3))(input_layer)
x = base_model(x)
x = Flatten()(x)
x = Dense(10, activation='softmax')(x)


model = Model(inputs=input_layer, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 23s 62ms/step - loss: 3.4904 - accuracy: 0.7462
# test_loss=3.4903616905212402
# test_accuracy=0.7462000250816345

# %% [markdown]
# ##（需放大圖成特定大小）將NASNetLarge進行FineTune

# %%
#NASNetLarge
import tensorflow.keras
#此處不能直接像之前模型一樣，因為InceptionV3所需圖檔大小至少要有75x75
#而Cifar10只有32x32
#若不修正則會出錯：ValueError: Input size must be at least 75x75; got `input_shape=(32, 32, 3)`
#base_model = tensorflow.keras.applications.InceptionV3(weights='imagenet',
#                               include_top=False,
#                               input_shape=(32, 32, 3))
base_model = tensorflow.keras.applications.NASNetLarge(weights='imagenet',
                               include_top=False,
                               input_shape=(331, 331, 3))

base_model.summary()
# Out:
# ...
# 343613440/343610240 [==============================] - 3s 0us/step
# Model: "NASNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_39 (InputLayer)           [(None, 331, 331, 3) 0
# __________________________________________________________________________________________________
# stem_conv1 (Conv2D)             (None, 165, 165, 96) 2592        input_39[0][0]
# __________________________________________________________________________________________________
# stem_bn1 (BatchNormalization)   (None, 165, 165, 96) 384         stem_conv1[0][0]
# __________________________________________________________________________________________________
# activation_970 (Activation)     (None, 165, 165, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#NASNetLarge
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D
from tensorflow.keras.models import Model

# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）

#重點是這裡要改
#此處不能直接像之前模型一樣，因為NASNetLarge所需圖檔大小必須為331x331
#而Cifar10只有32x32
#若不修正則會出錯：ValueError: Input size must be at least 331x331; got `input_shape=(32, 32, 3)`
#base_model = tensorflow.keras.applications.InceptionV3(weights='imagenet',
#                               include_top=False,
#                               input_shape=(32, 32, 3))
#此例特別將32x32的圖檔利用Keras的Lambda層長寬都直接擴增至(331,331,3)
base_model = tensorflow.keras.applications.NASNetLarge(weights='imagenet',
                               include_top=False,
                               input_shape=(331, 331, 3))

from tensorflow.keras import backend as K
from tensorflow.keras.layers import Lambda
#此例特別將32x32的圖檔利用Keras的Lambda層長寬都直接擴增至(331,331,3)

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])
print(f'layer_dict={layer_dict}')
#重點是這裡要改
#這層每次要跑1023秒太慢，導致跑不完100 epoch就被關掉，打算換一個
#x = layer_dict['normal_concat_11'].output
x = layer_dict['reduction_add_2_stem_1'].output
base_model = Model(inputs=base_model.input, outputs=x)


#在這裡需使用正規的Functional Model定義方式
from tensorflow.keras.layers import Input
import tensorflow as tf
input_layer = Input(shape=(32,32,3))
#x = Lambda(lambda img: K.resize_images(img, 11, 11, data_format='channels_last'), input_shape=(32, 32, 3))(input_layer)
x = Lambda(lambda img: tf.image.resize(img, (331,331)), input_shape=(32, 32, 3))(input_layer)
x = base_model(x)
x = Flatten()(x)
x = Dense(10, activation='softmax')(x)


model = Model(inputs=input_layer, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# layer_dict={'input_40': <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f333b2e14d0>, 'stem_conv1': <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f33c40ade90>, 'stem_bn1': <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f333ef99490>, 'activation_1230': <tensorflow.python.keras.layers.core.Activation object at 0x7f333efae110>, 'reduction_conv_1_stem_1': <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f333ef82390>, 'reduction_bn_1_stem_1': <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f333efaf0d0>, 'activation_1231': <tensorflow.python.keras.layers.core.Activation object at 0x7f333efb2550>, 'activation_1233': <tensorflow.python.keras.layers.core.Activation object at 0x7f333ef9d5d0>, 'separable_conv_1_pad_reduction_left1_stem_1': <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f333ef9dc90>, 'separable_conv_1_pad_reduction_right1_stem_1': 
# ...

# %% [markdown]
# ##（非Keras官方提供）將EfficientNetB0進行FineTune

# %%
#EfficientNetB0
import tensorflow.keras
base_model = tensorflow.keras.applications.EfficientNetB0(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))
base_model.summary()
# Out:
# ...
# 16711680/16705208 [==============================] - 0s 0us/step
# Model: "efficientnetb0"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_42 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 32, 32, 3)    0           input_42[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 32, 32, 3)    7           rescaling[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 33, 33, 3)    0           normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#EfficientNetB0
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.EfficientNetB0(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['block5c_add'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 4s 9ms/step - loss: 2.4605 - accuracy: 0.0998
# test_loss=2.4604837894439697
# test_accuracy=0.0997999981045723

# %% [markdown]
# ##（非Keras官方提供）將EfficientNetB1進行FineTune

# %%
#EfficientNetB1
import tensorflow.keras
base_model = tensorflow.keras.applications.EfficientNetB1(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))
base_model.summary()
# Out:
# ...
# 27025408/27018416 [==============================] - 0s 0us/step
# Model: "efficientnetb1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_44 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# rescaling_2 (Rescaling)         (None, 32, 32, 3)    0           input_44[0][0]
# __________________________________________________________________________________________________
# normalization_2 (Normalization) (None, 32, 32, 3)    7           rescaling_2[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 33, 33, 3)    0           normalization_2[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#EfficientNetB1
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.EfficientNetB1(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['block5c_add'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 4s 11ms/step - loss: 2.4564 - accuracy: 0.1363
# test_loss=2.4564037322998047
# test_accuracy=0.1362999975681305

# %% [markdown]
# ##（非Keras官方提供）將EfficientNetB2進行FineTune

# %%
#EfficientNetB2
import tensorflow.keras
base_model = tensorflow.keras.applications.EfficientNetB2(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))
base_model.summary()
# Out:
# ...
# 31793152/31790344 [==============================] - 0s 0us/step
# Model: "efficientnetb2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_46 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# rescaling_4 (Rescaling)         (None, 32, 32, 3)    0           input_46[0][0]
# __________________________________________________________________________________________________
# normalization_4 (Normalization) (None, 32, 32, 3)    7           rescaling_4[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 33, 33, 3)    0           normalization_4[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#EfficientNetB2
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.EfficientNetB2(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['block5c_add'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 5s 10ms/step - loss: 2.3599 - accuracy: 0.1197
# test_loss=2.3599069118499756
# test_accuracy=0.11969999969005585

# %% [markdown]
# ##（非Keras官方提供）將EfficientNetB3進行FineTune

# %%
#EfficientNetB3
import tensorflow.keras
base_model = tensorflow.keras.applications.EfficientNetB3(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))
base_model.summary()
# Out:
# ...
# 43941888/43941136 [==============================] - 1s 0us/step
# Model: "efficientnetb3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_48 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# rescaling_6 (Rescaling)         (None, 32, 32, 3)    0           input_48[0][0]
# __________________________________________________________________________________________________
# normalization_6 (Normalization) (None, 32, 32, 3)    7           rescaling_6[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 33, 33, 3)    0           normalization_6[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#EfficientNetB3
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.EfficientNetB3(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['block5c_add'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 5s 12ms/step - loss: 2.3353 - accuracy: 0.1307
# test_loss=2.3352608680725098
# test_accuracy=0.1307000070810318

# %% [markdown]
# ##（非Keras官方提供）將EfficientNetB4進行FineTune

# %%
#EfficientNetB4
import tensorflow.keras
base_model = tensorflow.keras.applications.EfficientNetB4(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))
base_model.summary()
# Out:
# ...
# 71688192/71686520 [==============================] - 1s 0us/step
# Model: "efficientnetb4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_50 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# rescaling_8 (Rescaling)         (None, 32, 32, 3)    0           input_50[0][0]
# __________________________________________________________________________________________________
# normalization_8 (Normalization) (None, 32, 32, 3)    7           rescaling_8[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 33, 33, 3)    0           normalization_8[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#EfficientNetB4
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.EfficientNetB4(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['block5c_add'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 6s 14ms/step - loss: 2.3615 - accuracy: 0.1016
# test_loss=2.361530065536499
# test_accuracy=0.10159999877214432

# %% [markdown]
# ##（非Keras官方提供）將EfficientNetB5進行FineTune

# %%
#EfficientNetB5
import tensorflow.keras
base_model = tensorflow.keras.applications.EfficientNetB5(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))
base_model.summary()
# Out:
# ...
# 115269632/115263384 [==============================] - 1s 0us/step
# Model: "efficientnetb5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_52 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# rescaling_10 (Rescaling)        (None, 32, 32, 3)    0           input_52[0][0]
# __________________________________________________________________________________________________
# normalization_10 (Normalization (None, 32, 32, 3)    7           rescaling_10[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 33, 33, 3)    0           normalization_10[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#EfficientNetB5
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.EfficientNetB5(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['block5c_add'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 7s 16ms/step - loss: 2.3434 - accuracy: 0.1001
# test_loss=2.343406915664673
# test_accuracy=0.10010000318288803

# %% [markdown]
# ##（非Keras官方提供）將EfficientNetB6進行FineTune

# %%
#EfficientNetB6
import tensorflow.keras
base_model = tensorflow.keras.applications.EfficientNetB6(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))
base_model.summary()
# Out:
# ...
# 165240832/165234480 [==============================] - 2s 0us/step
# Model: "efficientnetb6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_54 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# rescaling_12 (Rescaling)        (None, 32, 32, 3)    0           input_54[0][0]
# __________________________________________________________________________________________________
# normalization_12 (Normalization (None, 32, 32, 3)    7           rescaling_12[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 33, 33, 3)    0           normalization_12[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#EfficientNetB6
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.EfficientNetB6(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['block5c_add'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 8s 19ms/step - loss: 2.3838 - accuracy: 0.1000
# test_loss=2.3838260173797607
# test_accuracy=0.10000000149011612

# %% [markdown]
# ##（非Keras官方提供）將EfficientNetB7進行FineTune

# %%
#EfficientNetB7
import tensorflow.keras
base_model = tensorflow.keras.applications.EfficientNetB7(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))
base_model.summary()
# Out:
# ...
# 258080768/258076736 [==============================] - 2s 0us/step
# Model: "efficientnetb7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_56 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# rescaling_14 (Rescaling)        (None, 32, 32, 3)    0           input_56[0][0]
# __________________________________________________________________________________________________
# normalization_14 (Normalization (None, 32, 32, 3)    7           rescaling_14[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 33, 33, 3)    0           normalization_14[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#EfficientNetB7
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, MaxPooling2D

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /=255
X_test /=255

y_train = tensorflow.keras.utils.to_categorical(y_train, 10)
y_test = tensorflow.keras.utils.to_categorical(y_test, 10)
#開始載入整個模型（含架構、權重）
#from keras.models import load_model
#model = build_model()
#model=load_model('lenet_weights.h5')

#重點是這裡要改
base_model = tensorflow.keras.applications.EfficientNetB7(weights='imagenet',
                               include_top=False,
                               input_shape=(32, 32, 3))

for layer in base_model.layers:
     layer.trainable = False
#base_model.summary()
layer_dict = dict([(layer.name, layer) for layer in base_model.layers])

#重點是這裡要改
x = layer_dict['block5c_add'].output

x = Flatten()(x)
x = Dense(10, activation='softmax')(x)

from tensorflow.keras.models import Model
model = Model(inputs=base_model.input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train,
          batch_size=128,
          epochs=1,
          )
# 開始進行testing
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'test_loss={test_loss}')
print(f'test_accuracy={test_accuracy}')
# Out:
# ...
# 313/313 [==============================] - 9s 22ms/step - loss: 2.3610 - accuracy: 0.0999
# test_loss=2.3609564304351807
# test_accuracy=0.09989999979734421
